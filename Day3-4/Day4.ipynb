# %% [markdown]
# ## Day 4

# %%
# Numpy --> Library in Python for scientific computing. 
# It provides a high performance multi-dimensional array objects (ndarray)
import numpy as np
import pandas as pd

# %%
a = np.arange(10)
np.sum(a)
# Out:
# 45

# %%
np.min(a)
# Out:
# 0

# %%
np.max(a)
# Out:
# 9

# %%
# series (1D) -- { 'grades': [23,25,24,27,18] }
# dataframe (2D) --

# %%
import pandas as pd
pd.Series([2,3,4,5])
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
pd.Series([2,3,4,5], index=[11,12,13,14])
# Out:
# 11    2
# 12    3
# 13    4
# 14    5
# dtype: int64

# %%
s = pd.Series()

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
pd.Series( [ n*10 for n in range(10) ] )
# Out:
# 0     0
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# 6    60
# 7    70
# 8    80
# 9    90
# dtype: int64

# %%
phonebook = {'Aakash': '+91 92863572344', 'John': '+1 93664572322' }

# %%
phonebook
# Out:
# {'Aakash': '+91 92863572344', 'John': '+1 93664572322'}

# %%
pd.Series(phonebook)
# Out:
# Aakash    +91 92863572344
# John       +1 93664572322
# dtype: object

# %%
data = { 'year': [2008, 2010, 2011], 'attendees': [45, 57, 99] }

# %%
df = pd.DataFrame(data, index=['a', 'b', 'c'])

# %%
df.shape
# Out:
# (3, 2)

# %%
df
# Out:
#    year  attendees
# a  2008         45
# b  2010         57
# c  2011         99

# %%
df.size
# Out:
# 6

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([[2008,   45],
#        [2010,   57],
#        [2011,   99]])

# %%
pd.Series (phonebook)
# Out:
# Aakash    +91 92863572344
# John       +1 93664572322
# dtype: object

# %%
df
# Out:
#    year  attendees
# a  2008         45
# b  2010         57
# c  2011         99

# %%
df['year']
# Out:
# a    2008
# b    2010
# c    2011
# Name: year, dtype: int64

# %%
df['attendees']
# Out:
# a    45
# b    57
# c    99
# Name: attendees, dtype: int64

# %%
df['attendees'] += 7
# df['attendees'] = df['attendees'] + 7

# x = 10
# x = x + 1    OR   x += 1

# %%
df
# Out:
#    year  attendees
# a  2008         52
# b  2010         64
# c  2011        106

# %%
df['attendees'] + 100
# Out:
# a    152
# b    164
# c    206
# Name: attendees, dtype: int64

# %%
df
# Out:
#    year  attendees
# a  2008         52
# b  2010         64
# c  2011        106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 2 columns):
# year         3 non-null int64
# attendees    3 non-null int64
# dtypes: int64(2)
# memory usage: 152.0+ bytes

# %%
df.describe()
# Out:
#               year   attendees
# count     3.000000    3.000000
# mean   2009.666667   74.000000
# std       1.527525   28.354894
# min    2008.000000   52.000000
# 25%    2009.000000   58.000000
# 50%    2010.000000   64.000000
# 75%    2010.500000   85.000000
# max    2011.000000  106.000000

# %%
df = pd.read_csv('/Users/Ganesh/Desktop/Cognixia/Data/books.csv')

# %%
df.head(3)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
#
#                       authors         isbn13 language_code price  \
# 0  J.K. Rowling-Mary GrandPré  9780439785969           eng   652
# 1  J.K. Rowling-Mary GrandPré  9780439358071           eng   870
# 2  J.K. Rowling-Mary GrandPré  9780439554930           eng   320
#
#   ratings_count text_reviews_count
# 0       1944099              26249
# 1       1996446              27613
# 2       5629932              70390

# %%
df.count()
# Out:
# bookID                11003
# title                 11003
# authors               11003
# isbn13                11003
# language_code         11003
# price                 11003
# ratings_count         11003
# text_reviews_count    11003
# dtype: int64

# %%
df = pd.read_csv('/Users/Ganesh/Desktop/Cognixia/Data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
females = df[df['Sex'] == 'female']

# %%
females.count()
# Out:
# PassengerId    314
# Survived       314
# Pclass         314
# Name           314
# Sex            314
# Age            261
# SibSp          314
# Parch          314
# Ticket         314
# Fare           314
# Cabin           97
# Embarked       312
# dtype: int64

# %%
males = df[df['Sex'] == 'male']

# %%
males.count()
# Out:
# PassengerId    577
# Survived       577
# Pclass         577
# Name           577
# Sex            577
# Age            453
# SibSp          577
# Parch          577
# Ticket         577
# Fare           577
# Cabin          107
# Embarked       577
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
old = df[df.Age > 60]

# %%
old
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
old = df[ (df.Age > 60) & (df['Sex'] == 'female') ]

# %%
old
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 275  female  63.0      1      0   13502  77.9583    D7        S
# 483  female  63.0      0      0    4134   9.5875   NaN        S
# 829  female  62.0      0      0  113572  80.0000   B28      NaN

# %%
df.drop(labels=['PassengerId'], axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = df.drop(labels=['PassengerId'], axis=1)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv('/Users/Ganesh/Desktop/Cognixia/Data/titanic.csv')

# %%
df['Name'].apply(len).max()
# Out:
# 82

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# df = df.drop(labels=['PassengerId'], axis=1)
df.drop(labels=['PassengerId'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.drop(labels=['Ticket'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# 2  female  26.0      0      0   7.9250   NaN        S
# 3  female  35.0      1      0  53.1000  C123        S
# 4    male  35.0      0      0   8.0500   NaN        S

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
missing = df[df.isnull().any(axis=1)]

# %% [markdown]
# missing.head()

# %%
# df.Embarked
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
missing.count()
# Out:
# Survived    708
# Pclass      708
# Name        708
# Sex         708
# Age         531
# SibSp       708
# Parch       708
# Fare        708
# Cabin        21
# Embarked    706
# dtype: int64

# %%
df[df.Cabin.isna()].count()
# Out:
# Survived    687
# Pclass      687
# Name        687
# Sex         687
# Age         529
# SibSp       687
# Parch       687
# Fare        687
# Cabin         0
# Embarked    687
# dtype: int64

# %%
df[df.Age.isna()]
# Out:
#      Survived  Pclass                                      Name     Sex  Age  \
# 5           0       3                          Moran, Mr. James    male  NaN
# 17          1       2              Williams, Mr. Charles Eugene    male  NaN
# 19          1       3                   Masselmani, Mrs. Fatima  female  NaN
# 26          0       3                   Emir, Mr. Farred Chehab    male  NaN
# 28          1       3             O'Dwyer, Miss. Ellen "Nellie"  female  NaN
# ..        ...     ...                                       ...     ...  ...
# 859         0       3                          Razi, Mr. Raihed    male  NaN
# 863         0       3         Sage, Miss. Dorothy Edith "Dolly"  female  NaN
# 868         0       3               van Melkebeke, Mr. Philemon    male  NaN
# 878         0       3                        Laleff, Mr. Kristo    male  NaN
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female  NaN
#
#      SibSp  Parch     Fare Cabin Embarked
# ...

# %%
df[df.Embarked == 'C'].count()
# Out:
# Survived    168
# Pclass      168
# Name        168
# Sex         168
# Age         130
# SibSp       168
# Parch       168
# Fare        168
# Cabin        69
# Embarked    168
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 0           0       3                   Braund, Mr. Owen Harris    male  22.0
# 2           1       3                    Heikkinen, Miss. Laina  female  26.0
# 4           0       3                  Allen, Mr. William Henry    male  35.0
# 5           0       3                          Moran, Mr. James    male   NaN
# 7           0       3            Palsson, Master. Gosta Leonard    male   2.0
# ..        ...     ...                                       ...     ...   ...
# 884         0       3                    Sutehall, Mr. Henry Jr    male  25.0
# 885         0       3      Rice, Mrs. William (Margaret Norton)  female  39.0
# 886         0       2                     Montvila, Rev. Juozas    male  27.0
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890         0       3                       Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
df["Name"].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
df.Name.str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
df.Name.apply(len)
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
# how can we drop null?
# df.drop(, axis=0, inplace=True)

# %%
# df[df.Age.isna()]

# %%
df = pd.read_csv('/Users/Ganesh/Desktop/Cognixia/Data/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Cabin'].isna()].count()
# Out:
# PassengerId    687
# Survived       687
# Pclass         687
# Name           687
# Sex            687
# Age            529
# SibSp          687
# Parch          687
# Ticket         687
# Fare           687
# Cabin            0
# Embarked       687
# dtype: int64

# %%
df['Cabin'].dropna().unique()
#df['Cabin'] = df['Cabin'].dropna()
# Out:
# array(['C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27',
#        'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33', 'F G73', 'E31',
#        'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69', 'D47',
#        'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4',
#        'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77',
#        'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'D',
#        'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7',
#        'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128', 'D37',
#        'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104',
#        'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30',
#        'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22',
#        'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20',
#        'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126',
# ...

# %%
# Drop all rows where cabin is missing -- ToDo
# df['Cabin'] = df['Cabin'].dropna()
?????

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[[2]]
# Out:
#    PassengerId  Survived                                          Name  \
# 3            4         1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
#       Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 3  female  35.0      1      0  113803  53.1  C123        S

# %%
df.dropna(how='any', axis=0).count()
# Out:
# PassengerId    183
# Survived       183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64

# %%
df[df['Age'].isna()].count()
# Out:
# PassengerId    177
# Survived       177
# Name           177
# Sex            177
# Age              0
# SibSp          177
# Parch          177
# Ticket         177
# Fare           177
# Cabin           19
# Embarked       177
# dtype: int64

# %%
df2 = df['Age'].dropna()
df2.count()
# Out:
# 712

# %%
df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5            6         0                                   Moran, Mr. James
# 6            7         0                            McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C
# 3  female  35.0      1      0     113803  53.1000  C123        S
# 5    male   NaN      0      0     330877   8.4583   NaN        Q
# 6    male  54.0      0      0      17463  51.8625   E46        S

# %%
df.drop(df.iloc[:, 2:5], axis=1)
# Out:
#      PassengerId  Survived  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0              1         0      1      0   A/5 21171   7.2500   NaN        S
# 1              2         1      1      0    PC 17599  71.2833   C85        C
# 3              4         1      1      0      113803  53.1000  C123        S
# 5              6         0      0      0      330877   8.4583   NaN        Q
# 6              7         0      0      0       17463  51.8625   E46        S
# ..           ...       ...    ...    ...         ...      ...   ...      ...
# 886          887         0      0      0      211536  13.0000   NaN        S
# 887          888         1      0      0      112053  30.0000   B42        S
# 888          889         0      1      2  W./C. 6607  23.4500   NaN        S
# 889          890         1      0      0      111369  30.0000  C148        C
# 890          891         0      0      0      370376   7.7500   NaN        Q
#
# [889 rows x 8 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5            6         0                                   Moran, Mr. James
# 6            7         0                            McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C
# 3  female  35.0      1      0     113803  53.1000  C123        S
# 5    male   NaN      0      0     330877   8.4583   NaN        Q
# 6    male  54.0      0      0      17463  51.8625   E46        S

# %%
df.drop(df.loc[:, 'Name':'Age'].columns, axis=1)
# Out:
#      PassengerId  Survived  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0              1         0      1      0   A/5 21171   7.2500   NaN        S
# 1              2         1      1      0    PC 17599  71.2833   C85        C
# 3              4         1      1      0      113803  53.1000  C123        S
# 5              6         0      0      0      330877   8.4583   NaN        Q
# 6              7         0      0      0       17463  51.8625   E46        S
# ..           ...       ...    ...    ...         ...      ...   ...      ...
# 886          887         0      0      0      211536  13.0000   NaN        S
# 887          888         1      0      0      112053  30.0000   B42        S
# 888          889         0      1      2  W./C. 6607  23.4500   NaN        S
# 889          890         1      0      0      111369  30.0000  C148        C
# 890          891         0      0      0      370376   7.7500   NaN        Q
#
# [889 rows x 8 columns]

# %%
df.drop(df.index[3], inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 3      0     113803  53.1000  C123        S
# 4      0     373450   8.0500   NaN        S
# 5      0     330877   8.4583   NaN        Q

# %%
df.drop(labels=['Pclass'], axis=1, inplace=True)

# %%
# loc --> to get rows/cols from index
# iloc --> to get rows/cols from possition in the index

# %%
df.loc[2]
# Out:
# Survived                         1
# Pclass                           3
# Name        Heikkinen, Miss. Laina
# Sex                         female
# Age                             26
# SibSp                            0
# Parch                            0
# Fare                         7.925
# Cabin                          NaN
# Embarked                         S
# Name: 2, dtype: object

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# 2  female  26.0      0      0   7.9250   NaN        S
# 3  female  35.0      1      0  53.1000  C123        S
# 4    male  35.0      0      0   8.0500   NaN        S

# %%
df.loc[2:5]
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 2         1       3                        Heikkinen, Miss. Laina  female
# 3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         0       3                      Allen, Mr. William Henry    male
# 5         0       3                              Moran, Mr. James    male
#
#     Age  SibSp  Parch     Fare Cabin Embarked
# 2  26.0      0      0   7.9250   NaN        S
# 3  35.0      1      0  53.1000  C123        S
# 4  35.0      0      0   8.0500   NaN        S
# 5   NaN      0      0   8.4583   NaN        Q

# %%
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# ...

# %%
df = pd.read_excel('/Users/Ganesh/Desktop/Cognixia/Data/Superstore.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df[df['Postal Code'].isna()]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066 2018-12-05 2018-12-10  Standard Class
# 5274    5275  CA-2016-162887 2016-11-07 2016-11-09    Second Class
# 8798    8799  US-2017-150140 2017-04-06 2017-04-10  Standard Class
# 9146    9147  US-2017-165505 2017-01-23 2017-01-27  Standard Class
# 9147    9148  US-2017-165505 2017-01-23 2017-01-27  Standard Class
# 9148    9149  US-2017-165505 2017-01-23 2017-01-27  Standard Class
# 9386    9387  US-2018-127292 2018-01-19 2018-01-23  Standard Class
# 9387    9388  US-2018-127292 2018-01-19 2018-01-23  Standard Class
# 9388    9389  US-2018-127292 2018-01-19 2018-01-23  Standard Class
# 9389    9390  US-2018-127292 2018-01-19 2018-01-23  Standard Class
# 9741    9742  CA-2016-117086 2016-11-08 2016-11-12  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# 2234    QJ-19255      Quincy Jones    Corporate  United States  Burlington
# ...

# %%
df[df['Region'] == 'South'].count()
# Out:
# Row ID           1620
# Order ID         1620
# Order Date       1620
# Ship Date        1620
# Ship Mode        1620
# Customer ID      1620
# Customer Name    1620
# Segment          1620
# Country          1620
# City             1620
# State            1620
# Postal Code      1620
# Region           1620
# Product ID       1620
# Category         1620
# Sub-Category     1620
# Product Name     1620
# Sales            1620
# Quantity         1620
# Discount         1620
# Profit           1620
# dtype: int64

# %%
df['Customer Name'].str.upper()
# Out:
# 0            CLAIRE GUTE
# 1            CLAIRE GUTE
# 2        DARRIN VAN HUFF
# 3         SEAN O'DONNELL
# 4         SEAN O'DONNELL
#               ...
# 9989    TOM BOECKENHAUER
# 9990         DAVE BROOKS
# 9991         DAVE BROOKS
# 9992         DAVE BROOKS
# 9993        CHRIS CORTES
# Name: Customer Name, Length: 9994, dtype: object

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
def func(x):
    return '1' if x == 'South' else 0

# %%
df['Region'].apply(func)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 9989    1
# 9990    0
# 9991    0
# 9992    0
# 9993    0
# Name: Region, Length: 9994, dtype: object

# %%
df['Region'].apply(lambda x: '1' if x == 'South' else 0)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 9989    1
# 9990    0
# 9991    0
# 9992    0
# 9993    0
# Name: Region, Length: 9994, dtype: object

# %%
df['Customer Name'].apply(len).max()
# Out:
# 22

# %%
df.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch        Fare
# count   889.000000  889.000000  712.000000  889.000000  889.000000  889.000000
# mean    446.994376    0.383577   29.696868    0.524184    0.382452   32.258689
# std     256.786230    0.486531   14.544894    1.103705    0.806761   49.736052
# min       1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%     225.000000    0.000000   20.000000    0.000000    0.000000    7.895800
# 50%     447.000000    0.000000   28.000000    0.000000    0.000000   14.454200
# 75%     669.000000    1.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5            6         0                                   Moran, Mr. James
# 6            7         0                            McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C
# 3  female  35.0      1      0     113803  53.1000  C123        S
# 5    male   NaN      0      0     330877   8.4583   NaN        Q
# 6    male  54.0      0      0      17463  51.8625   E46        S

# %%
df.count()
# Out:
# PassengerId    889
# Survived       889
# Name           889
# Sex            889
# Age            712
# SibSp          889
# Parch          889
# Ticket         889
# Fare           889
# Cabin          204
# Embarked       887
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a1 = np.arange(10)
a2 = np.arange(10) * 2

# %%
plt.plot(a1)
plt.plot(a2)

# %%
plt.plot([2,5,3,7,9,3,4,8], 'g')
plt.plot([1,4,7,8,4,13,10], 'r--')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('First line plot')
plt.savefig('/Users/Ganesh/Desktop/first_line_plot.jpeg')

# %%
df = pd.read_csv('/Users/Ganesh/Desktop/Cognixia/Data/gas_prices.csv')

# %%
df.head()
# Out:
#      Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990.0        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991.0       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992.0       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993.0       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994.0       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
plt.plot(df['Year'], df['Australia'])
plt.plot(df['Year'], df['Canada'])
plt.plot(df['Year'], df['France'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
df.head()
# Out:
#      Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990.0        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991.0       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992.0       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993.0       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994.0       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
% matplotlib inline
for country in ["Australia", "Canada","France", "Germany","Italy","Japan","Mexico"]:
    plt.plot(df['Year'], df[country])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
titanic = pd.read_csv('/Users/Ganesh/Desktop/Cognixia/Data/titanic.csv')

# %%
titanic.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic.Sex.value_counts().plot('bar')
# Out:
# /Users/Ganesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
plt.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-271-bb3c5f7e493f> in <module>()
# ----> 1 plt.bar()
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'
